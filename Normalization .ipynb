# %% [markdown]
# # Normalization of Data

# %% [markdown]
# Import Library

# %%
import pandas as pd

# %% [markdown]
# Import the data

# %%
df = pd.read_csv('151006120126_GA OrderData_20150901-20150930.tab', sep = '\t')

# %% [markdown]
# Inspect the data

# %%
df.head()
# Out:
#    1/9/2015  AE Unnamed: 2  AR Unnamed: 4  BFMFBB  1-Sep-15 Unnamed: 7  \
# 0  1/9/2015  AE        NaN  AR        NaN  BZ5L4N  1-Sep-15        NaN
# 1  1/9/2015  AE        NaN  AR        NaN  EI8FTF  1-Sep-15        NaN
# 2  1/9/2015  AE        NaN  AR        NaN  FJ8MU2  1-Sep-15        NaN
# 3  1/9/2015  AE        NaN  AR        NaN  G7MCX2  1-Sep-15        NaN
# 4  1/9/2015  AE        NaN  AR        NaN  HCLHGW  1-Sep-15        NaN
#
#    DXB-AMM-DXB Unnamed: 9  ... Unnamed: 63 Unnamed: 64 Unnamed: 65  \
# 0  DXB-BKK-DXB        NaN  ...         NaN         NaN         NaN
# 1  DXB-IST-DXB        NaN  ...         NaN         NaN         NaN
# 2  DXB-CAN-DXB        NaN  ...         NaN         NaN         NaN
# 3  DXB-CAI-DXB        NaN  ...         NaN         NaN         NaN
# 4  DXB-BKK-DXB        NaN  ...         NaN         NaN         NaN
#
#    Unnamed: 66 Unnamed: 67  Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71  \
# ...

# %% [markdown]
# Drop the empty columns

# %%
df1 = df.dropna(axis=1)

# %% [markdown]
# Inspect the data

# %%
df1.head()
# Out:
#    1/9/2015  AE  BFMFBB  1-Sep-15 1/9/2015.1  14:40:50   16/9/2015  \
# 0  1/9/2015  AE  BZ5L4N  1-Sep-15   1/9/2015  21:24:52    7/9/2015
# 1  1/9/2015  AE  EI8FTF  1-Sep-15   1/9/2015  19:35:44  20/12/2015
# 2  1/9/2015  AE  FJ8MU2  1-Sep-15   1/9/2015  21:08:12    8/9/2015
# 3  1/9/2015  AE  G7MCX2  1-Sep-15   1/9/2015   8:47:23    3/9/2015
# 4  1/9/2015  AE  HCLHGW  1-Sep-15   1/9/2015  18:49:12   21/9/2015
#
#    No-PromoCode  United Arab Emirates organic  google (not set).1
# 0  No-PromoCode  United Arab Emirates     cpc  google     Booking
# 1  No-PromoCode  United Arab Emirates     cpc  google     Flights
# 2  No-PromoCode  United Arab Emirates     cpc  google     Flights
# 3  No-PromoCode  United Arab Emirates     cpc  google     Airline
# 4       AEPOLIC  United Arab Emirates     cpc  google     Flights

# %% [markdown]
# The fourth and the fifth column are the same but in different format. This can cause unneccsary redundancy, it is imperrative to remove one. I will remove the fourth column

# %%
df2 = df1.drop(df1.columns[3],axis=1)

# %%
This data has been normalize and

# %%
df2.head()
# Out:
#    1/9/2015  AE  BFMFBB 1/9/2015.1  14:40:50   16/9/2015  No-PromoCode  \
# 0  1/9/2015  AE  BZ5L4N   1/9/2015  21:24:52    7/9/2015  No-PromoCode
# 1  1/9/2015  AE  EI8FTF   1/9/2015  19:35:44  20/12/2015  No-PromoCode
# 2  1/9/2015  AE  FJ8MU2   1/9/2015  21:08:12    8/9/2015  No-PromoCode
# 3  1/9/2015  AE  G7MCX2   1/9/2015   8:47:23    3/9/2015  No-PromoCode
# 4  1/9/2015  AE  HCLHGW   1/9/2015  18:49:12   21/9/2015       AEPOLIC
#
#    United Arab Emirates organic  google (not set).1
# 0  United Arab Emirates     cpc  google     Booking
# 1  United Arab Emirates     cpc  google     Flights
# 2  United Arab Emirates     cpc  google     Flights
# 3  United Arab Emirates     cpc  google     Airline
# 4  United Arab Emirates     cpc  google     Flights

# %% [markdown]
# Removing duplicates

# %%
df3 = df2.drop_duplicates(keep=False)

# %%
df3.head()
# Out:
#    1/9/2015  AE  BFMFBB 1/9/2015.1  14:40:50   16/9/2015  No-PromoCode  \
# 0  1/9/2015  AE  BZ5L4N   1/9/2015  21:24:52    7/9/2015  No-PromoCode
# 1  1/9/2015  AE  EI8FTF   1/9/2015  19:35:44  20/12/2015  No-PromoCode
# 2  1/9/2015  AE  FJ8MU2   1/9/2015  21:08:12    8/9/2015  No-PromoCode
# 3  1/9/2015  AE  G7MCX2   1/9/2015   8:47:23    3/9/2015  No-PromoCode
# 4  1/9/2015  AE  HCLHGW   1/9/2015  18:49:12   21/9/2015       AEPOLIC
#
#    United Arab Emirates organic  google (not set).1
# 0  United Arab Emirates     cpc  google     Booking
# 1  United Arab Emirates     cpc  google     Flights
# 2  United Arab Emirates     cpc  google     Flights
# 3  United Arab Emirates     cpc  google     Airline
# 4  United Arab Emirates     cpc  google     Flights
